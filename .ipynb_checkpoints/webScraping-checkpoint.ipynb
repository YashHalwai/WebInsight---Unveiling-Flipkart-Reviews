# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq
import logging

# %%
flipkart_url = "https://www.flipkart.com/search?q=" + "redmi+12+5g"

# %%
flipkart_url
# Out:
# 'https://www.flipkart.com/search?q=redmi+12+5g'

# %%
urlclient = uReq(flipkart_url)

# %%
urlclient

# %%
flipkart_page = urlclient.read() # dump code

# %%
flipkart_html = bs(flipkart_page, 'html.parser')

# %%
flipkart_html
# Out:
# <!DOCTYPE html>
# ...

# %%
bigbox = flipkart_html.findAll("div", {"class" : "_1AtVbE col-12-12"}) # only 1 (find)

# %%
len(bigbox)
# Out:
# 30

# %%
bigbox
# Out:
# [<div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>CATEGORIES</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3zK8He" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_2qvBBJ _2Mji8F" href="/mobiles-accessories/pr?sid=tyy&amp;q=redmi+12+5g&amp;otracker=categorytree" title="Mobiles &amp; Accessories">Mobiles &amp; Accessories</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/mobiles/pr?sid=
# ...

# %%
bigbox[1]
# Out:
# <div class="_1AtVbE col-12-12"><a class="_1nY1tt" href="/buying-guide/mobiles?sid=tyy,4io&amp;otracker=bg_from_browse_lhs" title="Buying Guide"><div><span>Need help?</span></div><div class="_1mVNvF"><span>Help me decide</span><svg class="ViewtL" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg"><path class="_2Zt1Py" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></div><img alt="Buying Guide" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/buying-guide-illustration_4dd325.png"/></a></div>

# %%
bigbox[3].div.div.div.a['href']
# Out:
# '/redmi-12-5g-moonstone-silver-128-gb/p/itm0c8ba13f6fc5b?pid=MOBGS7JGZBZKPGGB&lid=LSTMOBGS7JGZBZKPGGBMBYTXQ&marketplace=FLIPKART&q=redmi+12+5g&store=tyy%2F4io&srno=s_1_2&otracker=search&fm=organic&iid=de79ff00-8480-4e8f-9305-12f57aca3b09.MOBGS7JGZBZKPGGB.SEARCH&ppt=None&ppn=None&ssid=84bcnwvxyo0000001703220235138&qH=201dcfde3768ac4b'

# %%
del bigbox[0:3]

# %%
productlink = "https://www.flipkart.com" + bigbox[3].div.div.div.a['href']

# %%
product_req = requests.get(productlink)

# %%
product_req
# Out:
# <Response [200]>

# %%
for i in bigbox:
    print("https://www.flipkart.com" + i.div.div.div.a['href'])
# Out:
# https://www.flipkart.com/redmi-12-5g-moonstone-silver-128-gb/p/itm0c8ba13f6fc5b?pid=MOBGS7JGZBZKPGGB&lid=LSTMOBGS7JGZBZKPGGBMBYTXQ&marketplace=FLIPKART&q=redmi+12+5g&store=tyy%2F4io&srno=s_1_2&otracker=search&fm=organic&iid=de79ff00-8480-4e8f-9305-12f57aca3b09.MOBGS7JGZBZKPGGB.SEARCH&ppt=None&ppn=None&ssid=84bcnwvxyo0000001703220235138&qH=201dcfde3768ac4b
# https://www.flipkart.com/redmi-12-5g-jade-black-128-gb/p/itm0c8ba13f6fc5b?pid=MOBGS9QU7QVWUWRD&lid=LSTMOBGS9QU7QVWUWRDPOZGEI&marketplace=FLIPKART&q=redmi+12+5g&store=tyy%2F4io&srno=s_1_3&otracker=search&fm=organic&iid=de79ff00-8480-4e8f-9305-12f57aca3b09.MOBGS9QU7QVWUWRD.SEARCH&ppt=None&ppn=None&ssid=84bcnwvxyo0000001703220235138&qH=201dcfde3768ac4b
# ...

# %%
product_html = bs(product_req.text,'html.parser')

# %%
product_html
# Out:
# <!DOCTYPE html>
# ...

# %%
comment_box = product_html.findAll("div", {"class" : "_16PBlm"})

# %%
comment_box
# Out:
# [<div class="_16PBlm"><div class="col"><div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">3<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Does the job</p></div><div class="row"><div class="t-ZTKy"><div><div class="">Best mobile</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr/blobio-imr_783634d7043e42a6b20cecb300bfd8a9.jpg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr/blobio-imr_b72d7749135143a0a8415abe6ab6d71e.jpg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div></div><div class="row _3n8db9"><div class="row"><p class="_2sc7ZR _2V5EHH">Dhananjay Khajbage</p><svg class="_2a1p_T" height="14" viewbox="0 0 12 12" width="14" xmlns="http://www.w3.o
# ...

# %%
len(comment_box)
# Out:
# 11

# %%
comment_box[0]
# Out:
# <div class="_16PBlm"><div class="col"><div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">3<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Does the job</p></div><div class="row"><div class="t-ZTKy"><div><div class="">Best mobile</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr/blobio-imr_783634d7043e42a6b20cecb300bfd8a9.jpg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr/blobio-imr_b72d7749135143a0a8415abe6ab6d71e.jpg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div></div><div class="row _3n8db9"><div class="row"><p class="_2sc7ZR _2V5EHH">Dhananjay Khajbage</p><svg class="_2a1p_T" height="14" viewbox="0 0 12 12" width="14" xmlns="http://www.w3.or
# ...

# %%
comment_box[0].div.div.find_all('p', {"class": "_2sc7ZR _2V5EHH"})[0]
# Out:
# <p class="_2sc7ZR _2V5EHH">Dhananjay Khajbage</p>

# %%
comment_box[0].div.div.find_all('p', {"class": "_2sc7ZR _2V5EHH"})[0].text
# Out:
# 'Dhananjay Khajbage'

# %%
for i in comment_box:
    print(i.div.div.find_all('p', {"class": "_2sc7ZR _2V5EHH"})[0].text)
# Out:
# Dhananjay Khajbage
# MUNUSAMY PERUMAL
# Rakesh Sarkar
# faiz ali
# Flipkart Customer
# Flipkart Customer
# Ghanshyam Chauhan
# Sushil Rajput
# MIRZA KAZIM Ali BAIG
# siddaram ikkalaki
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18000/34494112.py in <module>
#       1 for i in comment_box:
# ----> 2     print(i.div.div.find_all('p', {"class": "_2sc7ZR _2V5EHH"})[0].text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
comment_box[0].div.div.div.div.text
# Out:
# '3'

# %%
for i in comment_box:
    print(i.div.div.div.div.text)
# Out:
# 3
# 4
# 4
# 4
# 5
# 5
# 5
# 5
# 4
# 5
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18000/2621339938.py in <module>
#       1 for i in comment_box:
# ----> 2     print(i.div.div.div.div.text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
comment_box[0].div.div.div.p.text
# Out:
# 'Does the job'

# %%
for i in comment_box:
    print(i.div.div.div.p.text)
# Out:
# Does the job
# Pretty good
# Good
# Really Nice
# Awesome
# Great product
# Decent product
# Excellent
# Nice product
# Super!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18000/4044681715.py in <module>
#       1 for i in comment_box:
# ----> 2     print(i.div.div.div.p.text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
comment_box[0].div.div.findAll('div', {"class" : ""})[0].div.text
# Out:
# 'Best mobile'

# %%
for i in comment_box:
    print(i.div.div.findAll('div', {"class" : ""})[0].div.text)
# Out:
# Best mobile
# NICE MOBAILE LIGHT WEIGHT....
# Good product battery performance is not so good feet is 👌okay
# Camera not good but phone is good
# Good 👍🏻
# Nice phone , camera is avrage , bettery enough for a day  and design is good
# Good product
# Awesome and good look
# Nice phone for normal uses fancy design .Front cemra is only 8 megapixel, plz
# One of the best 5g phone in 15k
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18000/2126900062.py in <module>
#       1 for i in comment_box:
# ----> 2     print(i.div.div.findAll('div', {"class" : ""})[0].div.text)
#
# AttributeError: 'NoneType' object has no attribute 'div'
